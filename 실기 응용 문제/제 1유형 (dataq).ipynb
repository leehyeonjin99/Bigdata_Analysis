# %% [markdown]
# https://www.datamanim.com/dataset/03_dataq/main_p1.html

# %% [markdown]
# # Question 1
# mtcars 데이터셋(mtcars.csv)의 qsec 컬럼을 최소최대 척도(Min-Max Scale)로 변환한 후 0.5보다
# 큰 값을 가지는 레코드 수를 구하시오.

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

import pandas as pd
data=pd.read_csv('data/mtcars.csv', encoding='utf-8', index_col=0)
qsec=data[['qsec']]

data
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(qsec)
qsec_scaled=scaler.transform(qsec)
qsec_scaled
# Out:
# array([[0.23333333],
#        [0.3       ],
#        [0.48928571],
#        [0.58809524],
#        [0.3       ],
#        [0.68095238],
#        [0.15952381],
#        [0.6547619 ],
#        [1.        ],
#        [0.45238095],
#        [0.52380952],
#        [0.3452381 ],
#        [0.36904762],
#        [0.41666667],
#        [0.41428571],
#        [0.3952381 ],
#        [0.34761905],
#        [0.59166667],
#        [0.47857143],
#        [0.64285714],
#        [0.65595238],
#        [0.28214286],
#        [0.33333333],
#        [0.10833333],
#        [0.30357143],
#        [0.52380952],
#        [0.26190476],
#        [0.28571429],
#        [0.        ],
#        [0.11904762],
#        [0.01190476],
#        [0.48809524]])

# %%
print(len(qsec_scaled[qsec_scaled>0.5]))
# Out:
# 9

# %% [markdown]
# # Question 2
# mtcars 데이터셋(mtcars.csv)의 qsec 컬럼을 표준정규분포 데이터 표준화 (standardization) 변환 후 최대, 최소값을 각각 구하시오.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(qsec)
qsec_standard_scaler=scaler.transform(qsec)

# %%
qsec_standard_scaler.min()
# Out:
# -1.9039963517625231

# %%
qsec_standard_scaler.max()
# Out:
# 2.8719855384368587

# %%
qsec_standard_scaler.min()
# Out:
# -1.9039963517625231

# %% [markdown]
# # Question 3
# mtcars 데이터셋(mtcars.csv)의 wt 컬럼의 이상치(IQR 1.5 외부에 존재하는)값들을 outlier 변수에 저장하라

# %%
wt=data.wt

# %%
Q75=wt.quantile(0.75)
Q25=wt.quantile(0.25)
IQR=Q75-Q25
IQR
# Out:
# 1.02875

# %%
import numpy as np
outlier=np.array(wt[(wt<Q25-IQR*1.5)|(wt>Q75+IQR*1.5)])

# %%
outlier
# Out:
# array([5.25 , 5.424, 5.345])

# %% [markdown]
# # Question 4
# mtcars 데이터셋에서 mpg변수와 나머지 변수들의 상관계수를 구하여 다음과 같이 내림차순 정렬하여 표현하라

# %%
corr=pd.DataFrame(data.corr()['mpg'][1:])

# %%
corr.sort_values(ascending=False, inplace=True, by='mpg')

# %%
corr
# Out:
#            mpg
# drat  0.681172
# vs    0.664039
# am    0.599832
# gear  0.480285
# qsec  0.418684
# carb -0.550925
# hp   -0.776168
# disp -0.847551
# cyl  -0.852162
# wt   -0.867659

# %% [markdown]
# # Question 5
# mtcars 데이터셋에서 mpg변수를 제외하고 데이터 정규화 (standardscaler) 과정을 진행한 이후 PCA를 통해 변수 축소를 하려한다. 누적설명 분산량이 92%를 넘기기 위해서는 몇개의 주성분을 선택해야하는지 설명하라

# %% [markdown]
# # Question 6
# mtcars 의 index는 (업체명) - (모델명)으로 구성된다. (valiant는 업체명) mtcars에 ‘brand’ 컬럼을 추가하고 value 값으로 업체명을 입력하라
